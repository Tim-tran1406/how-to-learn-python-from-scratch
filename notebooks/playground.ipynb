# %% [markdown]
# # 🐍 Python Playground
#
# This is your scratchpad for the **How to Learn Python from Scratch** course.
#
# **How to use it:** copy any code example from the course into a cell below, then press **▶** (or `Shift`+`Enter`) to run it. Change things and run again — experimenting is how you learn!

# %%
print("Hello, Python!")

# %%
# Your turn — paste an example here and run it.
